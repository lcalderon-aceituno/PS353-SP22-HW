# %% [markdown]
# <a href="https://colab.research.google.com/github/lcalderon-aceituno/PS353-SP22-HW/blob/main/HW14_12_17_Advanced_Dynamics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Import dependencies 
from sympy import *
from sympy.plotting import plot
from sympy import symbols
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import pandas as pd
from sympy import Function,plot_parametric

# %% [markdown]
# # 12.17

# %% [markdown]
# ## part a

# %%
gamma = 1.3
w = 2*pi
w0 = 1.5*w
beta = w0/4
init = [0,0] # initial conditions

# %%
# r = phi dot
def drdt(t, r):
  phi= r[0]
  phidot = r[1]
  return [phidot, -2*beta*phidot-w0**2*sin(phi)+gamma*w0**2*cos(w*t)]

# %%
tspan = [0, 8]

# %%
sol = solve_ivp(drdt, tspan, init, dense_output=True, rtol = 1e-12)

# %%
t = np.linspace(0, 8, 10000) # grab 10000 time points 
r = sol.sol(t)
phi1 = r[0]

# %%
plt.plot(t, phi1);
plt.ylabel('$\phi$');
plt.xlabel('$t$');

# %% [markdown]
# The graph above demonstrates that the motion of the DDP is a superposition of linear motion and periodic oscillations.

# %% [markdown]
# ## part b

# %%
i = 0
newphi = []
for time in t:
  newphi.append(phi1[i] + 2*pi*time)
  i = i + 1

# %%
plt.plot(t, newphi);
plt.ylabel('$\phi + 2 \pi t$');
plt.xlabel('$t$');

# %% [markdown]
# In the plot above, we have gotten rid of the linear motion and are left with just the periodic part of the DDP's motion.

# %%
#@title Install whit-phys-util
# !pip install whit-phys-util

# %%
#@title Grab HW repo
import whit_phys_util as buc
repo = buc.local_repository("https://github.com/lcalderon-aceituno/PS353-SP22-HW")
